# %%
import sys
sys.path.append('../scripts/')
import CPM
import json
import pandas as pd
import itertools
import glypy

# %%
filename = '../data/unicarb_substructures.linkAmbiguous.matched.json'
filename2 = '../data/unicarb_substructures.linkAmbiguous.merged.json'

with open(filename, 'r') as f:
    substructure_data = json.load(f)
    
with open(filename2, 'r') as f2:
    substructure_id = json.load(f2)
    
substructure_db = pd.DataFrame(data=substructure_data)

# %%
# mx=109
# ((substructure_db.T[mx]) & (1/substructure_db[(mx+1)::].sum()==0  )).sum()

# %%
glypy.io.iupac.dumps((glypy.io.glycoct.loads(substructure_id[0])))
# Out:
# 'a-L-Fucp'

# %%
#print(CPM.conditional_vect('G56682BC', substructure_data))
#CPM.conditional_matrix('G56682BC', substructure_data)

#n = 10
cond= pd.concat([CPM.conditional_vect(gi, substructure_data,mode='substructure').T for gi in list(substructure_db.columns) ]).T
#cond_gly= pd.concat([CPM.conditional_vect(gi, substructure_data,mode='glycan').T for gi in list(substructure_db.columns)[0:n] ]).T
#cond= pd.concat([pd.DataFrame(CPM.conditional_matrix(gi, substructure_data)).T for gi in ['G56682BC', 'G65562ZE','G82348BZ', 'G42797SX', 'G24413UY', 'G28156XV']]).T

cond = cond.replace(float("NaN"),0)
cond
#cond_gly
#assert all(cond_gly.sum()<=1)
# Out:
#       G56682BC  G65562ZE  G53168IY  G33734YD  G10609HO  G63640QH  G84852GW  \
# 0          NaN       NaN       NaN  0.692537       NaN       NaN  0.364179
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN  0.043876  0.424132  0.021938  0.014625  0.223035
# 3          NaN       NaN  0.045028  0.435272  0.022514  0.015009  0.228893
# 4          NaN       NaN  0.044860  0.433645  0.022430  0.014953  0.228037
# 5     0.016949  0.037288       NaN       NaN       NaN       NaN  0.413559
# 6     0.011682  0.025701       NaN  0.542056       NaN  0.018692  0.285047
# 7     0.128205  0.282051       NaN       NaN       NaN       NaN       NaN
# 16         NaN       NaN       NaN  0.703030       NaN       NaN  0.369697
# 17         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 18         NaN       NaN  0.045627  0.441065  0.022814  0.015209  0.231939
# 19         NaN       NaN  0.051724  0.500000       NaN  0.017241  0.262931
# 20         NaN       NaN  0.044860  0.433645  0.022430  0.014953  0.228037
# 21         NaN       NaN  0.045028  0.435272  0.022514  0.015009  0.228893
# 22         NaN  0.047009       NaN       NaN       NaN       NaN  0.521368
# 23         NaN       NaN       NaN  0.571429       NaN       NaN  0.300493
# 24    0.250000  0.550000       NaN       NaN       NaN       NaN       NaN
# 33         NaN       NaN  0.444444       NaN  0.222222       NaN       NaN
# 36         NaN       NaN       NaN       NaN       NaN  1.000000       NaN
# 43    0.833333       NaN       NaN       NaN       NaN       NaN       NaN
# 49         NaN       NaN       NaN  0.716049       NaN       NaN  0.376543
# 50         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 51         NaN       NaN  0.045028  0.435272  0.022514  0.015009  0.228893
# 52         NaN       NaN  0.047337  0.453649  0.023669  0.015779  0.240631
# 53         NaN       NaN  0.051724  0.500000       NaN  0.017241  0.262931
# 55         NaN       NaN  0.044316  0.441233  0.023121  0.011561  0.235067
# 56         NaN       NaN       NaN       NaN       NaN       NaN  0.554545
# 57         NaN       NaN       NaN  0.628726       NaN       NaN  0.330623
# 58         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 59         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 951        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 952        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1022       NaN       NaN       NaN       NaN  0.363636       NaN       NaN
# 1053       NaN       NaN       NaN       NaN  1.000000       NaN       NaN
# 1056       NaN       NaN       NaN       NaN  0.857143       NaN       NaN
# 1065       NaN       NaN       NaN       NaN       NaN  1.000000       NaN
# 1073       NaN       NaN       NaN       NaN       NaN  1.000000       NaN
# 1163       NaN       NaN  1.000000       NaN       NaN       NaN       NaN
# 1178       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1180       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1186       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1494       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1499       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1505       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1507       NaN       NaN       NaN       NaN       NaN       NaN  0.991870
# 1513       NaN       NaN       NaN       NaN       NaN       NaN  0.625641
# 1519       NaN       NaN       NaN  1.000000       NaN       NaN  0.525862
# 1525       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1529       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1663       NaN       NaN       NaN       NaN  1.000000       NaN       NaN
# 1677       NaN       NaN       NaN       NaN       NaN  1.000000       NaN
# 1831       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1837       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2289       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2291       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2299       NaN       NaN       NaN       NaN       NaN       NaN  1.000000
# 2311       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2701       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3277       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#       G58667NI  G59576IJ  G90987JA
# 0     0.647761  0.020896  0.014925
# 1          NaN       NaN  0.151515
# 2     0.396709  0.012797  0.009141
# 3     0.407129  0.013133  0.009381
# 4     0.405607  0.013084  0.009346
# 5          NaN  0.023729       NaN
# 6     0.507009  0.016355       NaN
# 7          NaN       NaN       NaN
# 16    0.657576  0.021212  0.015152
# 17         NaN       NaN  0.151515
# 18    0.412548  0.009506  0.009506
# 19    0.467672       NaN  0.010776
# 20    0.405607  0.013084  0.009346
# 21    0.407129  0.013133  0.009381
# 22         NaN  0.029915       NaN
# 23    0.534483  0.017241       NaN
# 24         NaN       NaN       NaN
# 33         NaN       NaN       NaN
# 36         NaN       NaN       NaN
# 43         NaN       NaN       NaN
# 49    0.669753  0.021605  0.015432
# 50         NaN       NaN  0.151515
# 51    0.407129  0.013133  0.009381
# 52    0.424063  0.003945  0.009862
# 53    0.467672       NaN  0.010776
# 55    0.412331  0.013487  0.009634
# 56         NaN  0.031818       NaN
# 57    0.588076       NaN       NaN
# 58         NaN  0.350000       NaN
# 59         NaN  0.208333       NaN
# ...        ...       ...       ...
# 951        NaN  0.368421       NaN
# 952        NaN  0.636364       NaN
# 1022       NaN       NaN       NaN
# 1053       NaN       NaN       NaN
# 1056       NaN       NaN       NaN
# 1065       NaN       NaN       NaN
# 1073       NaN       NaN       NaN
# 1163       NaN       NaN       NaN
# 1178       NaN  0.388889       NaN
# 1180       NaN  0.437500       NaN
# 1186       NaN  1.000000       NaN
# 1494       NaN       NaN  0.833333
# 1499       NaN       NaN  0.227273
# 1503       NaN       NaN  0.151515
# 1505  0.794776       NaN  0.018657
# 1507       NaN       NaN       NaN
# 1513       NaN       NaN       NaN
# 1519  0.935345       NaN       NaN
# 1525  0.666667       NaN       NaN
# 1529       NaN  0.636364       NaN
# 1663       NaN       NaN       NaN
# 1677       NaN       NaN       NaN
# 1831       NaN  0.466667       NaN
# 1837       NaN  1.000000       NaN
# 2289       NaN       NaN  0.833333
# 2291       NaN       NaN  0.227273
# 2299       NaN       NaN       NaN
# 2311  1.000000       NaN       NaN
# 2701       NaN  1.000000       NaN
# 3277       NaN       NaN  1.000000
#
# [151 rows x 10 columns]

# %%
CPM.conditional_matrix_cbx('G56682BC', substructure_data)

# %%
list(range(10))[-1]
